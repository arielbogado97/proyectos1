# %% [markdown]
# ***Objetivo del proyecto: Visualizar el nivel de ocupación de las posiciones MZ 2.***

# %%
# !pip install --upgrade -q gspread

# %% [markdown]
# **Importamos la base de datos que se analizará, a través de la librería pandas.**

# %%
from google.colab import auth
auth.authenticate_user() 
import gspread
from oauth2client.client import GoogleCredentials
gc=gspread.authorize(GoogleCredentials.get_application_default())
worksheet=gc.open('Posiciones Mz 2').sheet1
rows=worksheet.get_all_values()
import pandas as pd
print(rows)
df=pd.DataFrame.from_records(rows)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df
# Out:
#                 0   ...                    18
# 0       Posiciones  ...          Storage Path
# 1         MZ-2-002  ...  [MZ-2-002-004-01-01]
# 2         MZ-2-002  ...  [MZ-2-002-004-01-01]
# 3         MZ-2-002  ...  [MZ-2-002-004-01-01]
# 4         MZ-2-002  ...  [MZ-2-002-004-01-01]
# ...            ...  ...                   ...
# 237402    MZ-2-050  ...  [MZ-2-050-061-04-04]
# 237403    MZ-2-050  ...  [MZ-2-050-061-04-05]
# 237404    MZ-2-050  ...  [MZ-2-050-061-04-05]
# 237405    MZ-2-050  ...  [MZ-2-050-061-04-05]
# 237406    MZ-2-050  ...  [MZ-2-050-061-04-05]
#
# [237407 rows x 19 columns]

# %% [markdown]
# **Importamos librerías que permiten los calculos numéricos (Numpy) y la generación de gráficos (Matplotlib).**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dfp=df.rename({0:'Posiciones',15:'Cantidad Total'},axis='columns')

# %%
dfp
# Out:
#         Posiciones  ...                    18
# 0       Posiciones  ...          Storage Path
# 1         MZ-2-002  ...  [MZ-2-002-004-01-01]
# 2         MZ-2-002  ...  [MZ-2-002-004-01-01]
# 3         MZ-2-002  ...  [MZ-2-002-004-01-01]
# 4         MZ-2-002  ...  [MZ-2-002-004-01-01]
# ...            ...  ...                   ...
# 237402    MZ-2-050  ...  [MZ-2-050-061-04-04]
# 237403    MZ-2-050  ...  [MZ-2-050-061-04-05]
# 237404    MZ-2-050  ...  [MZ-2-050-061-04-05]
# 237405    MZ-2-050  ...  [MZ-2-050-061-04-05]
# 237406    MZ-2-050  ...  [MZ-2-050-061-04-05]
#
# [237407 rows x 19 columns]

# %% [markdown]
# **Cantidad de productos por calle**.

# %%
dfp['Posiciones'].value_counts()
# Out:
# MZ-2-029      5516
# MZ-2-020      5472
# MZ-2-032      5360
# MZ-2-025      5354
# MZ-2-040      5328
# MZ-2-035      5287
# MZ-2-030      5284
# MZ-2-023      5273
# MZ-2-028      5270
# MZ-2-011      5215
# MZ-2-021      5201
# MZ-2-014      5198
# MZ-2-038      5186
# MZ-2-031      5164
# MZ-2-037      5147
# MZ-2-019      5128
# MZ-2-024      5122
# MZ-2-048      5114
# MZ-2-036      5085
# MZ-2-045      5072
# MZ-2-016      5062
# MZ-2-039      5038
# MZ-2-046      5037
# MZ-2-012      5021
# MZ-2-022      5013
# MZ-2-015      5009
# MZ-2-047      5002
# MZ-2-007      4982
# MZ-2-013      4927
# MZ-2-005      4867
# MZ-2-006      4863
# MZ-2-044      4850
# MZ-2-010      4850
# MZ-2-003      4801
# MZ-2-043      4733
# MZ-2-017      4715
# MZ-2-041      4619
# MZ-2-049      4595
# MZ-2-004      4535
# MZ-2-033      4499
# MZ-2-050      4466
# MZ-2-008      4416
# MZ-2-034      4387
# MZ-2-018      4375
# MZ-2-009      4342
# MZ-2-002      4209
# MZ-2-042      4185
# ...

# %% [markdown]
# **Gráfico de barras.**

# %%
dfp['Posiciones'].value_counts().plot(kind='bar',figsize=(15,15))
